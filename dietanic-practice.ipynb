# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['input']

# %% [markdown]
# # Part1. EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns  #data visualization library
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
import os
os.listdir('../input/input')  #to get dataset directory
# Out:
# ['train.csv', 'gender_submission.csv', 'test.csv']

# %%
data=pd.read_csv('../input/input/train.csv')

# %%
data.head()   #data preview(only 5)
# Out:
#    PassengerId  Survived  Pclass    ...        Fare Cabin  Embarked
# 0            1         0       3    ...      7.2500   NaN         S
# 1            2         1       1    ...     71.2833   C85         C
# 2            3         1       3    ...      7.9250   NaN         S
# 3            4         1       1    ...     53.1000  C123         S
# 4            5         0       3    ...      8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
data.isnull().sum()   #data null check->(Age,cabin,embarked) need to be reassigned
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# ## Feature1. sex(categorical)

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()  #women's survival rate is higher than men's

# %% [markdown]
# ## Feature2. Pclass(ordinal)

# %%
pd.crosstab(data.Pclass,data.Survived,margins=False).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_98447c0a_3784_11e9_9c34_0242ac130002row0_col0 {
#             background-color:  #ffff66;
#         }    #T_98447c0a_3784_11e9_9c34_0242ac130002row0_col1 {
#             background-color:  #008066;
#         }    #T_98447c0a_3784_11e9_9c34_0242ac130002row1_col0 {
#             background-color:  #f1f866;
#         }    #T_98447c0a_3784_11e9_9c34_0242ac130002row1_col1 {
#             background-color:  #ffff66;
#         }    #T_98447c0a_3784_11e9_9c34_0242ac130002row2_col0 {
#             background-color:  #008066;
#         }    #T_98447c0a_3784_11e9_9c34_0242ac130002row2_col1 {
#             background-color:  #58ac66;
#         }</style>
# <table id="T_98447c0a_3784_11e9_9c34_0242ac130002" >
# <thead>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Pclass</th>
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show() #Passengers in Pclass 3 were a lot higher, still the number of survival from them is very low

# %% [markdown]
# ## Sex & Pclass feature comparison

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=False).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_9886607a_3784_11e9_9c34_0242ac130002row0_col0 {
#             background-color:  #ffff66;
#         }    #T_9886607a_3784_11e9_9c34_0242ac130002row0_col1 {
#             background-color:  #ffff66;
#         }    #T_9886607a_3784_11e9_9c34_0242ac130002row0_col2 {
#             background-color:  #e6f266;
#         }    #T_9886607a_3784_11e9_9c34_0242ac130002row1_col0 {
#             background-color:  #008066;
#         }    #T_9886607a_3784_11e9_9c34_0242ac130002row1_col1 {
#             background-color:  #3f9f66;
#         }    #T_9886607a_3784_11e9_9c34_0242ac130002row1_col2 {
#             background-color:  #e6f266;
#         }    #T_9886607a_3784_11e9_9c34_0242ac130002row2_col0 {
#             background-color:  #289366;
#         }    #T_9886607a_3784_11e9_9c34_0242ac130002row2_col1 {
#             background-color:  #008066;
#         }    #T_9886607a_3784_11e9_9c34_0242ac130002row2_col2 {
#             background-color:  #008066;
# ...

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %% [markdown]
# ## Feature3. Age(continuous)

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
#    ## Reassign null values in Age feature
#    It is absurd to assign the mean age of dataset to a 4year kid. Therefore, we have to check the Name feature firstly and then assign the mean values of Mr and Mrs to the respective groups.

# %%
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.') #extracting strings which lie between A-Z or a-z and followed by a .(dot)

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style  type="text/css" >
#     #T_992d4ea8_3784_11e9_9c34_0242ac130002row0_col0 {
#             background-color:  #ffff66;
#         }    #T_992d4ea8_3784_11e9_9c34_0242ac130002row0_col1 {
#             background-color:  #ffff66;
#         }    #T_992d4ea8_3784_11e9_9c34_0242ac130002row0_col2 {
#             background-color:  #008066;
#         }    #T_992d4ea8_3784_11e9_9c34_0242ac130002row0_col3 {
#             background-color:  #ffff66;
#         }    #T_992d4ea8_3784_11e9_9c34_0242ac130002row0_col4 {
#             background-color:  #ffff66;
#         }    #T_992d4ea8_3784_11e9_9c34_0242ac130002row0_col5 {
#             background-color:  #ffff66;
#         }    #T_992d4ea8_3784_11e9_9c34_0242ac130002row0_col6 {
#             background-color:  #008066;
#         }    #T_992d4ea8_3784_11e9_9c34_0242ac130002row0_col7 {
#             background-color:  #ffff66;
#         }    #T_992d4ea8_3784_11e9_9c34_0242ac130002row0_col8 {
#             background-color:  #ffff66;
# ...

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True) #replacing some misspelled initials

# %%
data.groupby('Initial')['Age'].mean() #checking the average age by Initials
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
## Assigning the NaN Values with the Ceil values of the mean ages
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
data.Age.isnull().any() #null check for the last time
# Out:
# False

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
sns.factorplot('Pclass','Survived',col='Initial',data=data)
plt.show()  #women and child survived the most

# %% [markdown]
# ## Feature4. Embarked(categorical)

# %%
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived],margins=False).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_9a2a91d0_3784_11e9_9c34_0242ac130002row0_col0 {
#             background-color:  #fbfd66;
#         }    #T_9a2a91d0_3784_11e9_9c34_0242ac130002row0_col1 {
#             background-color:  #51a866;
#         }    #T_9a2a91d0_3784_11e9_9c34_0242ac130002row0_col2 {
#             background-color:  #e5f266;
#         }    #T_9a2a91d0_3784_11e9_9c34_0242ac130002row0_col3 {
#             background-color:  #7fbf66;
#         }    #T_9a2a91d0_3784_11e9_9c34_0242ac130002row1_col0 {
#             background-color:  #ffff66;
#         }    #T_9a2a91d0_3784_11e9_9c34_0242ac130002row1_col1 {
#             background-color:  #e6f266;
#         }    #T_9a2a91d0_3784_11e9_9c34_0242ac130002row1_col2 {
#             background-color:  #f8fc66;
#         }    #T_9a2a91d0_3784_11e9_9c34_0242ac130002row1_col3 {
#             background-color:  #f0f866;
#         }    #T_9a2a91d0_3784_11e9_9c34_0242ac130002row2_col0 {
#             background-color:  #daec66;
# ...

# %%
sns.factorplot('Embarked','Survived',data=data)
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()  #survival for Port C is the highest & Port S is the lowest

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot('Embarked',data=data,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('Embarked',hue='Sex',data=data,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked',hue='Survived',data=data,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked',hue='Pclass',data=data,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %%
sns.factorplot('Pclass','Survived',hue='Sex',col='Embarked',data=data)
plt.show()

# %% [markdown]
# # Reassign null values in Embarked

# %%
data['Embarked'].fillna('S',inplace=True)  #since port S is where maximum passengers boarded

# %%
data.Embarked.isnull().any()# null check
# Out:
# False

# %% [markdown]
# ## Feature5. SibSp(Discrete)
# SibSip = Sibling + Spouse

# %%
pd.crosstab([data.SibSp],data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_9b5a0f36_3784_11e9_9c34_0242ac130002row0_col0 {
#             background-color:  #008066;
#         }    #T_9b5a0f36_3784_11e9_9c34_0242ac130002row0_col1 {
#             background-color:  #008066;
#         }    #T_9b5a0f36_3784_11e9_9c34_0242ac130002row1_col0 {
#             background-color:  #c4e266;
#         }    #T_9b5a0f36_3784_11e9_9c34_0242ac130002row1_col1 {
#             background-color:  #77bb66;
#         }    #T_9b5a0f36_3784_11e9_9c34_0242ac130002row2_col0 {
#             background-color:  #f9fc66;
#         }    #T_9b5a0f36_3784_11e9_9c34_0242ac130002row2_col1 {
#             background-color:  #f0f866;
#         }    #T_9b5a0f36_3784_11e9_9c34_0242ac130002row3_col0 {
#             background-color:  #fbfd66;
#         }    #T_9b5a0f36_3784_11e9_9c34_0242ac130002row3_col1 {
#             background-color:  #fbfd66;
#         }    #T_9b5a0f36_3784_11e9_9c34_0242ac130002row4_col0 {
#             background-color:  #f9fc66;
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('SibSp','Survived',data=data,ax=ax[0])
ax[0].set_title('SibSp vs Survived')
sns.factorplot('SibSp','Survived',data=data,ax=ax[1])
ax[1].set_title('SibSp vs Survived')
plt.close(2)
plt.show() #all the large families in Pclass3(>3) died

# %% [markdown]
# ## Feature6. Fare(Continuous)

# %%
print('Highest Fare was:',data['Fare'].max())
print('Lowest Fare was:',data['Fare'].min())
print('Average Fare was:',data['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.2042079685746

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
#displot=연속값에 쓰는 함수
ax[0].set_title('Fares in Pclass 1')
sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show() #distribution is large in Pclass1

# %% [markdown]
# ## Correlation between features

# %%
sns.heatmap(data.corr(), annot=True, cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show() #1=positive/-1=negative
#ex)if increase in feature A leads to increase in feature B, they are positively correlated

# %% [markdown]
# # Part2. Feature Engineering & Data Cleaning
# This step is to eliminate redundasnt features

# %% [markdown]
# ## Convert continuous values into categorical values
# ex) Age feature

# %%
data['Age_band']=0
data.loc[data['Age']<=16,'Age_band']=0
data.loc[(data['Age']>16)&(data['Age']<=32),'Age_band']=1
data.loc[(data['Age']>32)&(data['Age']<=48),'Age_band']=2
data.loc[(data['Age']>48)&(data['Age']<=64),'Age_band']=3
data.loc[data['Age']>64,'Age_band']=4
data.head()
# Out:
#    PassengerId  Survived  Pclass    ...    Embarked Initial  Age_band
# 0            1         0       3    ...           S      Mr         1
# 1            2         1       1    ...           C     Mrs         2
# 2            3         1       3    ...           S    Miss         1
# 3            4         1       1    ...           S     Mrs         2
# 4            5         0       3    ...           S      Mr         2
#
# [5 rows x 14 columns]

# %%
data['Age_band'].value_counts().to_frame().style.background_gradient(cmap='summer') #checking the number of passengers in each band
# Out:
# <style  type="text/css" >
#     #T_9c6b617c_3784_11e9_9c34_0242ac130002row0_col0 {
#             background-color:  #ffff66;
#         }    #T_9c6b617c_3784_11e9_9c34_0242ac130002row1_col0 {
#             background-color:  #d8ec66;
#         }    #T_9c6b617c_3784_11e9_9c34_0242ac130002row2_col0 {
#             background-color:  #40a066;
#         }    #T_9c6b617c_3784_11e9_9c34_0242ac130002row3_col0 {
#             background-color:  #289366;
#         }    #T_9c6b617c_3784_11e9_9c34_0242ac130002row4_col0 {
#             background-color:  #008066;
#         }</style>
# <table id="T_9c6b617c_3784_11e9_9c34_0242ac130002" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Age_band</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_9c6b617c_3784_11e9_9c34_0242ac130002level0_row0" class="row_heading level0 row0" >1</th>
# ...

# %%
sns.factorplot('Age_band','Survived',data=data,col='Pclass')
plt.show() #survival rate decreases as the age increases

# %% [markdown]
# ## New Features = Family Size&Alone

# %%
data['Family_Size']=0
data['Family_Size']=data['Parch']+data['SibSp'] #combining Parch & SibSp features=family size
data['Alone']=0
data.loc[data.Family_Size==0,'Alone']=1#Alone

f,ax=plt.subplots(1,2,figsize=(18,6))
sns.factorplot('Family_Size','Survived',data=data,ax=ax[0])
ax[0].set_title('Family_Size vs Survived')
sns.factorplot('Alone','Survived',data=data,ax=ax[1])
ax[1].set_title('Alone vs Survived')
plt.close(2)
plt.close(3)
plt.show() #if you are alone, chances for survival is low

# %% [markdown]
# ## Fare feature conversion (continuous->ordinal)
# pandas.qcut = split/arrange the values according to the #of bins we've passed

# %%
data['Fare_Range']=pd.qcut(data['Fare'],4) #split Fare values into 4
data.groupby(['Fare_Range'])['Survived'].mean().to_frame().style.background_gradient(cmap='summer_r') #fare up, survival rate up
#furthermore, Fare_Range data needs to be converted into singleton values like Age_band
# Out:
# <style  type="text/css" >
#     #T_9d4c43e0_3784_11e9_9c34_0242ac130002row0_col0 {
#             background-color:  #ffff66;
#         }    #T_9d4c43e0_3784_11e9_9c34_0242ac130002row1_col0 {
#             background-color:  #b9dc66;
#         }    #T_9d4c43e0_3784_11e9_9c34_0242ac130002row2_col0 {
#             background-color:  #54aa66;
#         }    #T_9d4c43e0_3784_11e9_9c34_0242ac130002row3_col0 {
#             background-color:  #008066;
#         }</style>
# <table id="T_9d4c43e0_3784_11e9_9c34_0242ac130002" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Survived</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Fare_Range</th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_9d4c43e0_3784_11e9_9c34_0242ac130002level0_row0" class="row_heading level0 row0" >(-0.001, 7.91]</th>
# ...

# %% [markdown]
# ## Converting String values to Numeric

# %%
data['Sex'].replace(['male','female'],[0,1],inplace=True)
data['Embarked'].replace(['S','C','Q'],[0,1,2],inplace=True)
data['Initial'].replace(['Mr','Mrs','Miss','Master','Other'],[0,1,2,3,4],inplace=True)

# %%
data.drop(['Name','Age','Ticket','Fare','Cabin','Fare_Range','PassengerId'],axis=1,inplace=True)
#drop unnecessary or inconvertible features

sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2,annot_kws={'size':20})
fig=plt.gcf()
fig.set_size_inches(18,15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show() #more positively related features

# %% [markdown]
# # Part3. Predictive Modeling
# 1)Logistic Regression
#
# 2)Support Vector Machines(Linear and radial)
# "how do we divide the space with decision boundaries?"
#
# 3)Random Forest
# consists of several decision trees
# these trees make decisions and follow the majority's idea = 여러 트리에서 얻어진 결과를 평균/곱하기/과반수 투표로 가장 높은 가능성을 보이는 결과 도출
#
# 4)K-Nearest Neighbours
#
# 5)Naive Bayes
#
# 6)Decision Tree
# 예측력이 높은 변수를 우선적으로 순차적으로 배치&최종적인 예측 추출

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import svm 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics #accuracy measure
from sklearn.metrics import confusion_matrix

# %%
train,test=train_test_split(data,test_size=0.3,random_state=0,stratify=data['Survived'])
train_X=train[train.columns[1:]]
train_Y=train[train.columns[:1]]
test_X=test[test.columns[1:]]
test_Y=test[test.columns[:1]]
X=data[data.columns[1:]]
Y=data['Survived']

# %% [markdown]
# ### Radial Support Vector Machine(rbf-SVM)

# %%
model=svm.SVC(kernel='rbf',C=1,gamma=0.1)
model.fit(train_X,train_Y)
prediction1=model.predict(test_X)
print('accuracy for rbf SVM is',metrics.accuracy_score(prediction1,test_Y))
# Out:
# accuracy for rbf SVM is 0.835820895522388

# %% [markdown]
# ### Logistic Regression

# %%
model = LogisticRegression()
model.fit(train_X,train_Y)
prediction3=model.predict(test_X)
print('The accuracy of the Logistic Regression is',metrics.accuracy_score(prediction3,test_Y))
# Out:
# The accuracy of the Logistic Regression is 0.8283582089552238

# %% [markdown]
# ### Random Forests

# %%
model=RandomForestClassifier(n_estimators=100)
model.fit(train_X,train_Y)
prediction7=model.predict(test_X)
print('The accuracy of the Random Forests is',metrics.accuracy_score(prediction7,test_Y))
# Out:
# The accuracy of the Random Forests is 0.8134328358208955

# %% [markdown]
# ## K-Fold Cross Validation
# In case the data is imbalanced, to achieve a generalized model...
# 1. divide the dataset into k-subset
# 2. set the 1 part for testing and train the algorithm with the rest.
# 3. continue the process by changing the testset in each iteration

# %%
from sklearn.model_selection import KFold #for K-fold cross validation
from sklearn.model_selection import cross_val_score #score evaluation
from sklearn.model_selection import cross_val_predict #prediction
kfold = KFold(n_splits=10, random_state=22) #spliting data into 10 parts
xyz=[]
accuracy=[]
std=[]
classifiers=['Linear Svm','Radial Svm','Logistic Regression','KNN','Decision Tree','Naive Bayes','Random Forest']
models=[svm.SVC(kernel='linear'),svm.SVC(kernel='rbf'),LogisticRegression(),KNeighborsClassifier(n_neighbors=9),DecisionTreeClassifier(),GaussianNB(),RandomForestClassifier(n_estimators=100)]
for i in models:
    model = i;
    cv_result = cross_val_score(model,X,Y, cv = kfold,scoring="accuracy")
    cv_result = cv_result
    xyz.append(cv_result.mean())
    std.append(cv_result.std())
    accuracy.append(cv_result)
new_models_dataframe2=pd.DataFrame({'CV Mean':xyz,'Std':std},index=classifiers)       
new_models_dataframe2
# Out:
#                       CV Mean       Std
# Linear Svm           0.791223  0.045646
# Radial Svm           0.828290  0.034427
# Logistic Regression  0.801361  0.026964
# KNN                  0.810350  0.030160
# Decision Tree        0.803608  0.042326
# Naive Bayes          0.807004  0.034791
# Random Forest        0.800275  0.040760

# %%
plt.subplots(figsize=(12,6))
box=pd.DataFrame(accuracy,index=[classifiers])
box.T.boxplot()

# %%
new_models_dataframe2['CV Mean'].plot.barh(width=0.8)
plt.title('Average CV Mean Accuracy')
fig=plt.gcf()
fig.set_size_inches(8,5)
plt.show()
